# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('data/district_criminal_2020_anon_00.csv')
# Out:
# c:\users\chael\appdata\local\programs\python\python37\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (32) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.columns
# Out:
# Index(['HearingDate', 'HearingResult', 'HearingPlea', 'HearingContinuanceCode',
#        'HearingType', 'HearingCourtroom', 'fips', 'FiledDate', 'Locality',
#        'Status', 'DefenseAttorney', 'Address', 'Gender', 'Race', 'Charge',
#        'CodeSection', 'CaseType', 'Class', 'OffenseDate', 'ArrestDate',
#        'Complainant', 'AmendedCharge', 'AmendedCode', 'AmendedCaseType',
#        'FinalDisposition', 'SentenceTime', 'SentenceSuspendedTime',
#        'ProbationType', 'ProbationTime', 'ProbationStarts',
#        'OperatorLicenseSuspensionTime', 'RestrictionEffectiveDate',
#        'RestrictionEndDate', 'OperatorLicenseRestrictionCodes', 'Fine',
#        'Costs', 'FineCostsDue', 'FineCostsPaid', 'FineCostsPaidDate', 'VASAP',
#        'FineCostsPastDue', 'person_id'],
#       dtype='object')

# %%
df = df[df['CaseType'] == 'Misdemeanor']
df.drop(['CaseType'], axis=1, inplace=True) 
print(df.shape)
df.head()
# Out:
# (68592, 41)
#    HearingDate HearingResult HearingPlea HearingContinuanceCode HearingType  \
# 43  2020-02-26     Finalized         NaN                    NaN         NaN
# 47  2020-02-26     Finalized         NaN                    NaN         NaN
# 49  2020-02-26     Finalized         NaN                    NaN         NaN
# 70  2020-02-26     Finalized         NaN                    NaN         NaN
# 77  2020-02-26     Finalized         NaN                    NaN         NaN
#
#    HearingCourtroom  fips   FiledDate            Locality  \
# 43              NaN    99  2020-01-27  KING GEORGE COUNTY
# 47              NaN    99  2020-01-09  KING GEORGE COUNTY
# 49              NaN    99  2020-01-02  COMMONWEALTH OF VA
# 70              NaN    99  2020-01-24  KING GEORGE COUNTY
# 77              NaN    99  2020-01-09  KING GEORGE COUNTY
#
#                  Status  ... RestrictionEndDate  \
# 43  Released On Summons  ...                NaN
# ...

# %%
df.Locality.value_counts().nlargest(10)
# Out:
# COMMONWEALTH OF VA     43221
# VIRGINIA BEACH          2054
# CHESTERFIELD            1555
# COUNTY OF BRUNSWICK     1213
# SUSSEX                  1160
# COUNTY OF  FAIRFAX      1142
# NEWPORT NEWS            1003
# ARLINGTON                961
# CITY OF RICHMOND         872
# COUNTY OF FAIRFAX        860
# Name: Locality, dtype: int64

# %%
df.DefenseAttorney.unique()
# Out:
# array([nan, 'TOPP', 'MILES, MEGAN', ..., 'TAYLOR, JAMES T',
#        'WRIGHT, NICK T', 'PHILLIPS, C GREGORY'], dtype=object)

# %%
df.to_csv('data/dcm_2020_1.csv')

# %%
df = pd.read_csv('data/district_criminal_2020_anon_01.csv')
# Out:
# c:\users\chael\appdata\local\programs\python\python37\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (32) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df = df[df['CaseType'] == 'Misdemeanor']
df.drop(['CaseType'], axis=1, inplace=True) 
print(df.shape)
df.head()
# Out:
# (83220, 41)
#    HearingDate HearingResult HearingPlea HearingContinuanceCode   HearingType  \
# 10  2020-02-13     Finalized         NaN                    NaN  Adjudicatory
# 11  2020-02-03     Finalized  Not Guilty                    NaN  Adjudicatory
# 15  2020-01-28     Finalized         NaN                    NaN  Adjudicatory
# 16  2020-01-28     Finalized      Guilty                    NaN  Adjudicatory
# 22  2020-02-13     Finalized      Guilty                    NaN           NaN
#
#    HearingCourtroom  fips   FiledDate            Locality  \
# 10              NaN   145  2020-01-22  COMMONWEALTH OF VA
# 11                A   550  2019-12-17          CHESAPEAKE
# 15                5   153  2019-10-30  COMMONWEALTH OF VA
# 16                5   153  2019-10-30  COMMONWEALTH OF VA
# 22              NaN    89  2019-12-10        HENRY COUNTY
#
#                       Status  ... RestrictionEndDate  \
# 10       Released On Summons  ...                NaN
# ...

# %%
df.Locality.value_counts().nlargest(10)
# Out:
# COMMONWEALTH OF VA     50904
# COUNTY OF BRUNSWICK     5184
# VIRGINIA BEACH          3376
# CITY OF RICHMOND        2732
# ARLINGTON               2466
# HENRICO COUNTY          2422
# GREENSVILLE COUNTY      1822
# SHERIFF HOPEWELL        1709
# NORFOLK                 1472
# EXMORE                   978
# Name: Locality, dtype: int64

# %%
df.to_csv('data/dcm_2020_2.csv')

# %%
df = pd.read_csv('data/district_criminal_2020_anon_02.csv')
print(df.shape)

df = df[df['CaseType'] == 'Misdemeanor']
df.drop(['CaseType'], axis=1, inplace=True) 
print(df.shape)
df.head()

df.to_csv('data/dcm_2020_3.csv')
# Out:
# c:\users\chael\appdata\local\programs\python\python37\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (29,32) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# (250000, 42)
# (84748, 41)

# %%
df = pd.read_csv('data/district_criminal_2020_anon_03.csv')
print(df.shape)

df = df[df['CaseType'] == 'Misdemeanor']
df.drop(['CaseType'], axis=1, inplace=True) 
print(df.shape)
df.head()

df.to_csv('data/dcm_2020_4.csv')
# Out:
# (250000, 42)
# (88995, 41)

# %%
df = pd.read_csv('data/district_criminal_2020_anon_04.csv')
print(df.shape)

df = df[df['CaseType'] == 'Misdemeanor']
df.drop(['CaseType'], axis=1, inplace=True) 
print(df.shape)
df.head()

df.to_csv('data/dcm_2020_5.csv')
# Out:
# c:\users\chael\appdata\local\programs\python\python37\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (3,5,32) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# (250000, 42)
# (80022, 41)

# %%
df = pd.read_csv('data/district_criminal_2020_anon_05.csv')
print(df.shape)

df = df[df['CaseType'] == 'Misdemeanor']
df.drop(['CaseType'], axis=1, inplace=True) 
print(df.shape)
df.head()

df.to_csv('data/dcm_2020_6.csv')
# Out:
# c:\users\chael\appdata\local\programs\python\python37\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (32) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# (212577, 42)
# (82905, 41)

# %%
# concatenate 
df1 = pd.read_csv('data/dcm_2020_1.csv')
df2 = pd.read_csv('data/dcm_2020_2.csv')
df3 = pd.read_csv('data/dcm_2020_3.csv')
df4 = pd.read_csv('data/dcm_2020_4.csv')
df5 = pd.read_csv('data/dcm_2020_5.csv')
df6 = pd.read_csv('data/dcm_2020_6.csv')

df = pd.concat([df1, df2, df3, df4, df5, df6], ignore_index=True)
print(df.shape)
df.head()
# Out:
# c:\users\chael\appdata\local\programs\python\python37\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (32) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# c:\users\chael\appdata\local\programs\python\python37\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (29,32) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# (488482, 42)
#    Unnamed: 0 HearingDate HearingResult HearingPlea HearingContinuanceCode  \
# 0          43  2020-02-26     Finalized         NaN                    NaN
# 1          47  2020-02-26     Finalized         NaN                    NaN
# 2          49  2020-02-26     Finalized         NaN                    NaN
# 3          70  2020-02-26     Finalized         NaN                    NaN
# ...

# %%
# what columns are there?
df.columns
# Out:
# Index(['Unnamed: 0', 'HearingDate', 'HearingResult', 'HearingPlea',
#        'HearingContinuanceCode', 'HearingType', 'HearingCourtroom', 'fips',
#        'FiledDate', 'Locality', 'Status', 'DefenseAttorney', 'Address',
#        'Gender', 'Race', 'Charge', 'CodeSection', 'Class', 'OffenseDate',
#        'ArrestDate', 'Complainant', 'AmendedCharge', 'AmendedCode',
#        'AmendedCaseType', 'FinalDisposition', 'SentenceTime',
#        'SentenceSuspendedTime', 'ProbationType', 'ProbationTime',
#        'ProbationStarts', 'OperatorLicenseSuspensionTime',
#        'RestrictionEffectiveDate', 'RestrictionEndDate',
#        'OperatorLicenseRestrictionCodes', 'Fine', 'Costs', 'FineCostsDue',
#        'FineCostsPaid', 'FineCostsPaidDate', 'VASAP', 'FineCostsPastDue',
#        'person_id'],
#       dtype='object')

# %%
# remove unnecessary columns
df.drop(['Unnamed: 0', 'AmendedCharge', 'AmendedCode', 'AmendedCaseType', 'person_id', 'Complainant' ], axis=1, inplace=True)
print(df.shape)
# Out:
# (488482, 36)

# %%
df.Locality.value_counts().nlargest(10)
# Out:
# COMMONWEALTH OF VA     313122
# HENRICO COUNTY          12055
# VIRGINIA BEACH          10917
# CHESTERFIELD             9279
# COUNTY OF  FAIRFAX       8098
# COUNTY OF BRUNSWICK      7075
# GREENSVILLE COUNTY       6066
# PRINCE WILLIAM CO        5036
# NEWPORT NEWS             4783
# CHESAPEAKE               4688
# Name: Locality, dtype: int64

# %%
df.DefenseAttorney.value_counts().nlargest(10)
# Out:
# PUBLIC DEFENDER         20412
# PD                      12770
# PUB DEF                  2662
# PENDLETON                2183
# JOYNER                   1418
# P DEF                    1168
# PUBLIC DEFENDER(TSR)      828
# SARSOUR, JAD              811
# MARTIN                    727
# CLARY                     715
# Name: DefenseAttorney, dtype: int64

# %%
df['DefenseAttorney'] = df['DefenseAttorney'].str.replace('PD', 'PUBLIC DEFENDER')
df['DefenseAttorney'] = df['DefenseAttorney'].str.replace('PUB DEF', 'PUBLIC DEFENDER')
df['DefenseAttorney'] = df['DefenseAttorney'].str.replace('P DEF', 'PUBLIC DEFENDER')
df['DefenseAttorney'] = df['DefenseAttorney'].str.replace('PUBLIC DEFENDER(TSR)', 'PUBLIC DEFENDER')

df.DefenseAttorney.value_counts().nlargest(10)
# Out:
# PUBLIC DEFENDER         37012
# PENDLETON                2183
# JOYNER                   1418
# PUBLIC DEFENDER(TSR)      828
# SARSOUR, JAD              811
# MARTIN                    727
# CLARY                     715
# REMINGTON                 664
# WOOD                      661
# MILES, MEGAN              543
# Name: DefenseAttorney, dtype: int64

# %%
df['DefenseAttorney'] = df['DefenseAttorney'].str.replace("(", '')
df['DefenseAttorney'] = df['DefenseAttorney'].str.replace(")", '')
df.DefenseAttorney.value_counts().nlargest(10)
# Out:
# PUBLIC DEFENDER       37013
# PENDLETON              2183
# JOYNER                 1418
# PUBLIC DEFENDERTSR      830
# SARSOUR, JAD            811
# MARTIN                  727
# CLARY                   715
# REMINGTON               664
# WOOD                    661
# MILES, MEGAN            543
# Name: DefenseAttorney, dtype: int64

# %%
df['DefenseAttorney'] = df['DefenseAttorney'].str.replace('PUBLIC DEFENDERTSR', 'PUBLIC DEFENDER')
df.DefenseAttorney.value_counts().nlargest(10)
# Out:
# PUBLIC DEFENDER    37843
# PENDLETON           2183
# JOYNER              1418
# SARSOUR, JAD         811
# MARTIN               727
# CLARY                715
# REMINGTON            664
# WOOD                 661
# MILES, MEGAN         543
# JOYNER, JASON        522
# Name: DefenseAttorney, dtype: int64

# %%
# create empty column (initially fill it with nan values)
df['Attorney'] = np.nan

for i in range(len(df)):
    if type(df['DefenseAttorney'][i]) == float:
        df['Attorney'][i] = np.nan
    else:
        if df['DefenseAttorney'][i] == 'PUBLIC DEFENDER':
            df['Attorney'][i] = 'Public'
        else:
            df['Attorney'][i] = 'Private'
            
df.head()
# Out:
# c:\users\chael\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# c:\users\chael\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# c:\users\chael\appdata\local\programs\python\python37\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
df.Attorney.value_counts().plot(kind='barh')

# drop 'DefenseAttorney' column
df.drop(['DefenseAttorney'], axis=1, inplace=True)
print(df.shape)
# Out:
# (488482, 36)

# %%
# get only the zip codes from the address
df['zip'] = df['Address'].str.extract(r'(\d{5}\-?\d{0,4})')

# then drop Address column since we now have the column for zip codes
df.drop(['Address'], axis=1, inplace=True) 

df['zip'].head(10)
# Out:
# 0    22485
# 1    22485
# 2    22485
# 3    22407
# 4    22406
# 5    23223
# 6    23224
# 7    23224
# 8    26301
# 9    23224
# Name: zip, dtype: object

# %%
df['Attorney'].isna().sum() / len(df)
# Out:
# 0.501738037430243

# %%
# drop columns with more than 45% of nan values
df = df.dropna(thresh=len(df) * 0.45, axis=1)
df.columns
# Out:
# Index(['HearingDate', 'HearingResult', 'HearingType', 'HearingCourtroom',
#        'fips', 'FiledDate', 'Locality', 'Status', 'Gender', 'Race', 'Charge',
#        'CodeSection', 'Class', 'OffenseDate', 'FinalDisposition',
#        'SentenceTime', 'SentenceSuspendedTime', 'ProbationTime',
#        'OperatorLicenseSuspensionTime', 'Fine', 'Costs', 'Attorney', 'zip'],
#       dtype='object')

# %%
df.to_csv('data/dcm_2020.csv')

# %%
df = pd.read_csv('data/dcm_2020.csv')
df.drop(['Unnamed: 0'], axis=1, inplace=True) 
df.head()
# Out:
# c:\users\chael\appdata\local\programs\python\python37\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (23) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#   HearingDate HearingResult HearingType HearingCourtroom  fips   FiledDate  \
# 0  2020-02-26     Finalized         NaN              NaN    99  2020-01-27
# 1  2020-02-26     Finalized         NaN              NaN    99  2020-01-09
# 2  2020-02-26     Finalized         NaN              NaN    99  2020-01-02
# 3  2020-02-26     Finalized         NaN              NaN    99  2020-01-24
# 4  2020-02-26     Finalized         NaN              NaN    99  2020-01-09
#
#              Locality               Status Gender     Race  ... OffenseDate  \
# 0  KING GEORGE COUNTY  Released On Summons   Male    White  ...  2020-01-16
# 1  KING GEORGE COUNTY  Released On Summons   Male    White  ...  2020-01-01
# ...

# %%
# create 'duration' column (HearingDate - FiledDate)

# change data types
df['HearingDate'] = pd.to_datetime(df.HearingDate)
df['FiledDate'] = pd.to_datetime(df.FiledDate)


df['Duration'] = (df['HearingDate'] - df['FiledDate']).dt.days
df['Duration']
# Out:
# 0          30
# 1          48
# 2          55
# 3          33
# 4          48
#          ...
# 488477     96
# 488478    131
# 488479    131
# 488480    131
# 488481    512
# Name: Duration, Length: 488482, dtype: int64

# %%
df.to_csv('data/dcm_2020.csv')

# %%
df = pd.read_csv('data/dcm_2020.csv')
df.drop(['Unnamed: 0'], axis=1, inplace=True) 
df.head()
# Out:
# c:\users\chael\appdata\local\programs\python\python37\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (23) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#   HearingDate HearingResult HearingType HearingCourtroom  fips   FiledDate  \
# 0  2020-02-26     Finalized         NaN              NaN    99  2020-01-27
# 1  2020-02-26     Finalized         NaN              NaN    99  2020-01-09
# 2  2020-02-26     Finalized         NaN              NaN    99  2020-01-02
# 3  2020-02-26     Finalized         NaN              NaN    99  2020-01-24
# 4  2020-02-26     Finalized         NaN              NaN    99  2020-01-09
#
#              Locality               Status Gender     Race  ...  \
# 0  KING GEORGE COUNTY  Released On Summons   Male    White  ...
# 1  KING GEORGE COUNTY  Released On Summons   Male    White  ...
# ...

# %%
options = ['Guilty', 'Guilty in Absentia', 'Nolle Prosequi', 'Dismissed', 'Not Guilty', 'Dismissed/Other', 'Not Guilty/Insanity']
fd = df[df['FinalDisposition'].isin(options)]
fd.head()
# Out:
#   HearingDate HearingResult HearingType HearingCourtroom  fips   FiledDate  \
# 0  2020-02-26     Finalized         NaN              NaN    99  2020-01-27
# 1  2020-02-26     Finalized         NaN              NaN    99  2020-01-09
# 3  2020-02-26     Finalized         NaN              NaN    99  2020-01-24
# 4  2020-02-26     Finalized         NaN              NaN    99  2020-01-09
# 5  2020-02-28     Finalized         NaN              210   762  2020-01-27
#
#              Locality               Status Gender     Race  ...  \
# 0  KING GEORGE COUNTY  Released On Summons   Male    White  ...
# 1  KING GEORGE COUNTY  Released On Summons   Male    White  ...
# 3  KING GEORGE COUNTY  Released On Summons   Male  Unknown  ...
# 4  KING GEORGE COUNTY  Released On Summons   Male    White  ...
# 5  COMMONWEALTH OF VA              Custody   Male    White  ...
#
#   FinalDisposition SentenceTime SentenceSuspendedTime ProbationTime  \
# ...

# %%
# simplify final disposition to binary variable (either guilty or not guilty)
# create new column, 'fd'
df['fd'] = np.nan

guilty = ['Guilty', 'Guilty in Absentia']
no_guilty = ['Nolle Prosequi', 'Dismissed', 'Not Guilty', 'Dismissed/Other', 'Not Guilty/Insanity']

for i in range(len(df)):
    if df['FinalDisposition'][i] in guilty:
        df['fd'][i] = "guilty"
    elif df['FinalDisposition'][i] in no_guilty:
        df['fd'][i] = "no_guilty"
        
df['fd'].head()
# Out:
# c:\users\chael\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.
# c:\users\chael\appdata\local\programs\python\python37\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# c:\users\chael\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
df['fd'].value_counts().plot(kind='barh', color='red')
print(df['fd'].value_counts())
# Out:
# guilty       175290
# no_guilty    144305
# Name: fd, dtype: int64

# %%
df.to_csv('data/dcm_2020.csv')
